# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\sahga\OneDrive\Desktop\IMDb Movies India.csv", encoding='latin-1')

# %%
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                             #Homecoming -2021.0   90 min   Drama, Musical
# 3                                 #Yaaram -2019.0  110 min  Comedy, Romance
# 4                       ...And Once Again -2010.0  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga -1988.0      NaN           Action
# 15505                               Zulmi -1999.0  129 min    Action, Drama
# 15506                           Zulmi Raj -2005.0      NaN           Action
# 15507                       Zulmi Shikari -1988.0      NaN           Action
# 15508                        Zulm-O-Sitam -1998.0  130 min    Action, Drama
#
# ...

# %%
data.shape
# Out:
# (15509, 10)

# %%
data.ndim
# Out:
# 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#                Year       Rating
# count  14981.000000  7919.000000
# mean   -1987.012215     5.841621
# std       25.416689     1.381777
# min    -2022.000000     1.100000
# 25%    -2009.000000     4.900000
# 50%    -1991.000000     6.000000
# 75%    -1968.000000     6.800000
# max    -1913.000000    10.000000

# %%
data.head(10)
# Out:
#                                  Name    Year Duration  \
# 0                                         NaN      NaN
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min
# 2                         #Homecoming -2021.0   90 min
# 3                             #Yaaram -2019.0  110 min
# 4                   ...And Once Again -2010.0  105 min
# 5                ...Aur Pyaar Ho Gaya -1997.0  147 min
# 6                           ...Yahaan -2005.0  142 min
# 7                      .in for Motion -2008.0   59 min
# 8                  ?: A Question Mark -2012.0   82 min
# 9                            @Andheri -2014.0  116 min
#
#                        Genre  Rating  Votes            Director  \
# 0                      Drama     NaN    NaN       J.S. Randhawa
# 1                      Drama     7.0      8       Gaurav Bakshi
# 2             Drama, Musical     NaN    NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4     35          Ovais Khan
# ...

# %%
data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi) -2019.0  109 min
# 3                                 #Yaaram -2019.0  110 min
# 5                    ...Aur Pyaar Ho Gaya -1997.0  147 min
# 6                               ...Yahaan -2005.0  142 min
# 8                      ?: A Question Mark -2012.0   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan -2015.0  115 min
# 15494                            Zubeidaa -2001.0  153 min
# 15503                     Zulm Ki Zanjeer -1989.0  125 min
# 15505                               Zulmi -1999.0  129 min
# 15508                        Zulm-O-Sitam -1998.0  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %%
data.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
# create histogram for movie ratings.

plt.figure(figsize=(10, 6))
plt.hist(data['Rating'], bins=20, edgecolor='black', color = 'red')
plt.title('Histogram of Movie Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Count the frequency of each genre.
genre_counts = data['Genre'].value_counts()

top_40_genres = genre_counts.head(40)

# Set Seaborn style.
sns.set(style='whitegrid')

plt.figure(figsize=(12, 6))
sns.barplot(x=top_40_genres.index, y=top_40_genres.values, palette='viridis')
plt.title('Top 20 Movie Genres')
plt.xlabel('Genre')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
# create bar graph for genres by average rating.

average_ratings_by_genre = data.groupby('Genre')['Rating'].mean()

sorted_genres = average_ratings_by_genre.sort_values(ascending=False)

top_50_genres = sorted_genres.head(50)

plt.figure(figsize=(12, 6))
top_50_genres.plot(kind='bar', color='purple')
plt.title('Top 50 Genres by Average Rating')
plt.xlabel('Genre')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate average ratings for each genre.
average_ratings_by_genre = data.groupby('Genre')['Rating'].mean()

# Filter genres with average rating greater than 7.
high_rated_genres = average_ratings_by_genre[average_ratings_by_genre > 7]

plt.figure(figsize=(12, 6))
high_rated_genres.plot(kind='bar', color='green')
plt.title('Genres with Average Rating Greater than 7')
plt.xlabel('Genre')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %%
average_ratings_by_genre = data.groupby('Director')['Rating'].mean()

sorted_genres = average_ratings_by_genre.sort_values(ascending=False)


top_50_genres = sorted_genres.head(50)

plt.figure(figsize=(12, 6))
top_50_genres.plot(kind='bar', color='brown')
plt.title('Top 50 Director by Average Rating')
plt.xlabel('Genre')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate average ratings for each combination of genre and director.
average_ratings_by_genre_director = data.groupby(['Genre', 'Director'])['Rating'].mean().unstack()

top_directors = data['Director'].value_counts().head(30).index

# Filter the average ratings data for the top directors.
average_ratings_top_directors = average_ratings_by_genre_director[top_directors]

plt.figure(figsize=(12, 8))
sns.heatmap(average_ratings_top_directors, cmap='YlGnBu', annot=True, fmt=".1f")
plt.title('Average Ratings by Genre and Director (Top 30 Directors)')
plt.xlabel('Director')
plt.ylabel('Genre')
plt.xticks(rotation=90)
plt.show()

# %%
# Count the occurrences of each actor in Actor 1 column.
actor1_counts = data['Actor 1'].value_counts()

top_50_actors = actor1_counts.head(50)

# Plot a bar chart of top 50 actors by occurrence.
plt.figure(figsize=(12, 6))
top_50_actors.plot(kind='bar', color='orange')
plt.title('Top 50 Actors (Actor 1) by Occurrence')
plt.xlabel('Actor')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=90)
plt.show()

# %%
# Count the occurrences of each actor in Actor 2 column.
actor2_counts = data['Actor 2'].value_counts()

top_50_actors = actor2_counts.head(50)

plt.figure(figsize=(12, 6))
top_50_actors.plot(kind='bar', color='yellow')
plt.title('Top 50 Actors (Actor 2) by Occurrence')
plt.xlabel('Actor')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=90)
plt.show()

# %%
# Count the occurrences of each actor in Actor 3 column.
actor3_counts = data['Actor 3'].value_counts()

top_50_actors = actor3_counts.head(50)

plt.figure(figsize=(12, 6))
top_50_actors.plot(kind='bar', color='pink')
plt.title('Top 50 Actors (Actor 3) by Occurrence')
plt.xlabel('Actor')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate average ratings for each actor in Actor 1 column.
average_ratings_by_actor1 = data.groupby('Actor 1')['Rating'].mean()

top_50_actors = average_ratings_by_actor1.nlargest(50)

plt.figure(figsize=(12, 6))
top_50_actors.plot(kind='bar', color='blue')
plt.title('Top 50 Actors (Actor 1) by Average Rating')
plt.xlabel('Actor')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate average ratings for each combination of genre and actor 1.
average_ratings_by_genre_actor = data.groupby(['Genre', 'Actor 1'])['Rating'].mean().unstack()

# Select the top 30 actor 1 by the number of movies.
top_actor = data['Actor 1'].value_counts().head(30).index

# Filter the average ratings data for the top directors.
average_ratings_top_actor = average_ratings_by_genre_actor[top_actor]

plt.figure(figsize=(12, 8))
sns.heatmap(average_ratings_top_actor, cmap='YlGnBu', annot=True, fmt=".1f")
plt.title('Average Ratings by Genre and Director (Top 30 Actor 1)')
plt.xlabel('Actor 1')
plt.ylabel('Genre')
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate average ratings for each actor in Actor 2 column.
average_ratings_by_actor2 = data.groupby('Actor 2')['Rating'].mean()

top_30_actors = average_ratings_by_actor2.nlargest(50)

plt.figure(figsize=(12, 6))
top_30_actors.plot(kind='bar', color='black')
plt.title('Top 30 Actors (Actor 2) by Average Rating')
plt.xlabel('Actor')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate average ratings for each combination of genre and actor 2.
average_ratings_by_genre_actor = data.groupby(['Genre', 'Actor 2'])['Rating'].mean().unstack()

# Select the top 30 actor 2 by the number of movies.
top_actor = data['Actor 2'].value_counts().head(30).index

# Filter the average ratings data for the top directors.
average_ratings_top_actor = average_ratings_by_genre_actor[top_actor]

plt.figure(figsize=(12, 8))
sns.heatmap(average_ratings_top_actor, cmap='YlGnBu', annot=True, fmt=".1f")
plt.title('Average Ratings by Genre and Director (Top 30 Actor 2)')
plt.xlabel('Actor 2')
plt.ylabel('Genre')
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate average ratings for each actor in Actor 3 column.
average_ratings_by_actor3 = data.groupby('Actor 3')['Rating'].mean()

# Get the top 30 actors by average rating.
top_30_actors = average_ratings_by_actor3.nlargest(50)

# Plot a bar chart of top 30 actors by average rating.
plt.figure(figsize=(12, 6))
top_30_actors.plot(kind='bar', color='green')
plt.title('Top 30 Actors (Actor 3) by Average Rating')
plt.xlabel('Actor')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate average ratings for each combination of genre and actor 3.
average_ratings_by_genre_actor = data.groupby(['Genre', 'Actor 3'])['Rating'].mean().unstack()

# Select the top 30 actor 3 by the number of movies.
top_actor = data['Actor 3'].value_counts().head(30).index

# Filter the average ratings data for the top directors.
average_ratings_top_actor = average_ratings_by_genre_actor[top_actor]

plt.figure(figsize=(12, 8))
sns.heatmap(average_ratings_top_actor, cmap='YlGnBu', annot=True, fmt=".1f")
plt.title('Average Ratings by Genre and Director (Top 30 Actor 3)')
plt.xlabel('Actor 3')
plt.ylabel('Genre')
plt.xticks(rotation=90)
plt.show()

# %%
# Select numeric columns for the pair plot.
numeric_columns = ['Year', 'Duration', 'Votes', 'Rating']

# Create a pair plot.
sns.pairplot(data[numeric_columns])
plt.show()

# %%
# Group data by Year and calculate the mean rating for each year.
ratings_by_year = data.groupby('Year')['Rating'].mean()

# Plot a line chart of ratings over years.
plt.figure(figsize=(10, 6))
ratings_by_year.plot(kind='line', marker='o')
plt.title('Average Ratings Over Years')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.grid()
plt.show()

# %%
# Remove the Name, Year, Votes and Duration columns.

columns_to_remove = ['Name', 'Votes','Duration','Year']
data = data.drop(columns=columns_to_remove)

# %%
data
# Out:
#                            Genre  Rating         Director          Actor 1  \
# 1                          Drama     7.0    Gaurav Bakshi     Rasika Dugal
# 3                Comedy, Romance     4.4       Ovais Khan          Prateik
# 5         Comedy, Drama, Musical     4.7     Rahul Rawail       Bobby Deol
# 6            Drama, Romance, War     7.4   Shoojit Sircar  Jimmy Sheirgill
# 8      Horror, Mystery, Thriller     5.6    Allyson Patel        Yash Dave
# ...                          ...     ...              ...              ...
# 15493                      Drama     6.1      Mozez Singh    Vicky Kaushal
# 15494  Biography, Drama, History     6.2    Shyam Benegal   Karisma Kapoor
# 15503       Action, Crime, Drama     5.8  S.P. Muthuraman      Chiranjeevi
# 15505              Action, Drama     4.5       Kuku Kohli     Akshay Kumar
# 15508              Action, Drama     6.2     K.C. Bokadia       Dharmendra
#
#                       Actor 2           Actor 3
# ...

# %%
# Count the number of movies per director.
director_movie_counts = data['Director'].value_counts().head(10)

plt.figure(figsize=(12, 6))
director_movie_counts.plot(kind='bar', color='green')
plt.title('Top Directors by Number of Movies')
plt.xlabel('Director')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# Encode categorical variables.
encoder = OneHotEncoder(drop='first')
encoded_features = encoder.fit_transform(data[['Genre', 'Director', 'Actor 1', 'Actor 2', 'Actor 3']])

# %%
# Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(encoded_features, data['Rating'], test_size=0.2, random_state=42)

# Initialize and train the model.
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set.
y_pred = model.predict(X_test)

# Calculate RMSE and R-squared
rmse = mean_squared_error(y_test, y_pred, squared=False)
r_squared = r2_score(y_test, y_pred)

print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared: {r_squared}")
# Out:
# Root Mean Squared Error (RMSE): 3.205996105405834
# R-squared: -4.550666286530486

# %%
# Test example.
genre = "Horror"
director = "Rahul Rawail"
actor1 = "Bobby Deol"
actor2 = "Aishwarya Rai Bachchan"
actor3 = "Shammi Kapoor"

# Create a dataframe with inputs.
user_input = pd.DataFrame({
    'Genre': [genre],
    'Director': [director],
    'Actor 1': [actor1],
    'Actor 2': [actor2],
    'Actor 3': [actor3]
})

# Preprocess user input using the encoder.
encoded_user_input = encoder.transform(user_input)

# Predict the rating using the trained model.
predicted_rating = model.predict(encoded_user_input)


print(f"Predicted Rating: {predicted_rating[0]}")
# Out:
# Predicted Rating: 3.699099961897436

# %%
data
# Out:
#                            Genre  Rating         Director          Actor 1  \
# 1                          Drama     7.0    Gaurav Bakshi     Rasika Dugal
# 3                Comedy, Romance     4.4       Ovais Khan          Prateik
# 5         Comedy, Drama, Musical     4.7     Rahul Rawail       Bobby Deol
# 6            Drama, Romance, War     7.4   Shoojit Sircar  Jimmy Sheirgill
# 8      Horror, Mystery, Thriller     5.6    Allyson Patel        Yash Dave
# ...                          ...     ...              ...              ...
# 15493                      Drama     6.1      Mozez Singh    Vicky Kaushal
# 15494  Biography, Drama, History     6.2    Shyam Benegal   Karisma Kapoor
# 15503       Action, Crime, Drama     5.8  S.P. Muthuraman      Chiranjeevi
# 15505              Action, Drama     4.5       Kuku Kohli     Akshay Kumar
# 15508              Action, Drama     6.2     K.C. Bokadia       Dharmendra
#
#                       Actor 2           Actor 3
# ...
